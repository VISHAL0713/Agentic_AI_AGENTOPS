# %% [markdown]
# ## A small LangChain agent with custom middleware

# %% [markdown]
# ## Install packages

# %%
# !pip install -U "langchain>=1.3.14"
# !pip install  langchain-openai langchain-community langgraph python-dotenv langchain-mcp-adapters langchain-chroma chromadb pypdf
# Out:
# Requirement already satisfied: langchain>=1.3.14 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (1.3.16)
# Collecting langchain>=1.3.14
#   Downloading langchain-1.3.18-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain>=1.3.14) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain>=1.3.14) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain>=1.3.14) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (3.8.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (0.4.2)
# Requirement already satisfied: anyio in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (4.14.2)
# Requirement already satisfied: certifi in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.0.2)
# Requirement already satisfied: idna in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2.4)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2.2.0)
# Downloading langchain-1.3.18-py3-none-any.whl (148 kB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.16
#     Uninstalling langchain-1.3.16:
#       Successfully uninstalled langchain-1.3.16
# Successfully installed langchain-1.3.18
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-openai in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (1.4.2)
# Requirement already satisfied: langchain-community in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (0.4.2)
# Requirement already satisfied: langgraph in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (1.2.11)
# Requirement already satisfied: python-dotenv in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-mcp-adapters in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (0.3.2)
# Requirement already satisfied: langchain-chroma in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (1.5.9)
# Requirement already satisfied: pypdf in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (6.16.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.3 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (1.6.0)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (2.48.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.10.10)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.0.25)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: mcp<2.0.0,>=1.24.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-mcp-adapters) (1.29.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-mcp-adapters) (4.16.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.3)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.21.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: packaging>=24.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (26.3)
# Requirement already satisfied: pyproject_hooks in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (4.14.2)
# Requirement already satisfied: certifi in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.17.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.5.3->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.5.3->langchain-openai) (0.0.18)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.5.3->langchain-openai) (0.17.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: websockets<16,>=14 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (0.0.32)
# Requirement already satisfied: pywin32>=310 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (312)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (3.4.8)
# Requirement already satisfied: starlette>=0.27 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (1.6.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (0.4.2)
# Requirement already satisfied: flatbuffers in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.35.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\visha\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.0.3)
# Requirement already satisfied: regex in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2023.12.25)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: httptools>=0.8.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: filelock in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.3->langchain-openai) (2.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (50.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (2.1.1)
# Requirement already satisfied: pycparser in c:\users\visha\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (3.0)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (C:\Users\visha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from getpass import getpass

if not os.environ.get("OPENROUTER_API_KEY"):
    api_key = os.environ["OPENROUTER_API_KEY"] = getpass("OpenRouter API key: ")
    print(f"OpenRouter API key set in environment variable OPENROUTER_API_KEY: {api_key[0:4]}")
# Out:
# OpenRouter API key set in environment variable OPENROUTER_API_KEY: sk-o

# %%
from langchain_openai import ChatOpenAI

# OpenRouter exposes an OpenAI-compatible API, so ChatOpenAI works with a custom base_url
model = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0,
    api_key=os.environ["OPENROUTER_API_KEY"],
    base_url="https://openrouter.ai/api/v1",
)
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.18', 'langchain-openai': '1.4.2'}}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000029AE455A180>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000029AE44F03B0>, root_client=<openai.OpenAI object at 0x0000029AE3B24C20>, root_async_client=<openai.AsyncOpenAI object at 0x0000029AE44F2E10>, model_name='openai/gpt-4o-mini', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://openrouter.ai/api/v1', stream_chunk_timeout=120.0)
